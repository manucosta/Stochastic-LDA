# %% [markdown]
# # Stochastic Variational Inference for LDA

# %% [markdown]
# ## Introducción

# %% [markdown]
# En el presente notebook se realiza una implementación del algoritmo para topic modelling, Latent Dirichlet Allocation (LDA), en su versión con Stochastic Variational Inference. La implementación trata de apegarse a lo propuesto por Hoffman, Blei y Wang en [Stochastic Variational Inference](http://www.columbia.edu/~jwp2128/Papers/HoffmanBleiWangPaisley2013.pdf).
# Otros trabajos que fueron tomados como referencia son:
#  * Para un panorama más amplio sobre LDA: [Inference Methods for Latent Dirichlet Allocation](http://times.cs.uiuc.edu/course/598f16/notes/lda-survey.pdf);
#  * Para una explicación más detallada sobre la Mean-Field Variational Family: [Variational Inference: A Review for Statisticians](https://arxiv.org/pdf/1601.00670.pdf)
#
# Adicionalmente, la idea de implementar LDA surgió de un intento previo de querer implementar la propuesta de Wang y Blei, en [Collaborative Topic Modeling for Recommending Scientific Articles](http://www.cs.columbia.edu/~blei/papers/WangBlei2011.pdf), para Sistemas de Recomendación. De hecho el dataset utilizado aqui es el mismo que usan ellos. No descarto implementar este paper como siguiente paso.

# %% [markdown]
# ## Marco teórico

# %% [markdown]
# Asumiendo K tópicos, y D documentos, cada uno con N palabras (por simplicidad asumo documentos de igual longitud) pertenecientes a un vocabulario de tamaño V; el modelo generativo es el siguiente:
#
# 1. Generamos tópicos $\beta_k$ ~ Dirichlet($\eta,\dots,\eta$) para cada $k\in \{0,\dots,K-1\}$
# 2. Para cada documento $d \in \{0,\dots, D-1\}$:
#     3. Generamos $\theta_d$ ~ Dirichlet($\alpha,\dots,\alpha$)
#     4. Para cada palabra $w \in \{0,\dots, N-1\}$:
#         5. Generamos la asignación de tema $z_{dn}$ ~ Multinomial($\theta_d$)
#         6. Generamos la palabra $w_{dn}$ ~ Multinomial($\beta_{z_{dn}}$)
#
# Los parámetros involucrados son:
# * $\beta_k$, el tópico $k$. Un tópico consiste básicamente en un vector de probabilidad de longitud V, que modela la distribución de las distintas palabras en el vocabulario para ese tema
# * $\theta_d$, la proporción de los tópicos para el documento $d$. Nuevamente es un vector de probabilidades, que en este caso apunta a modelar la participación parcial de los distintos temas para un mismo documento. El hecho de que se permita que un documento pertenezca a un mixture de tópicos en lugar de uno solo, es una de las principales virtudes de LDA. __Esta es la principal variable sobre la que nos interesa poder hacer inferencia__.
# * $z_{dn}$, es la asignación del tópico de la palabra $n$ en el domunento $d$
# * $w_{dn}$, es la palabra $n$ del documento $d$. Pertenece al tópico $z_{dn}$

# %% [markdown]
# ## Dataset

# %% [markdown]
# El dataset fue descargado de http://www.cs.cmu.edu/~chongw/data/citeulike/. El mismo contiene información del sitio http://www.citeulike.org/, que le permite a investigadores armar sus bibliotecas de papers y recibir recomendaciones en base a las mismas. En particular yo no uso la información referente a los usuarios y sus bibliotecas, si no que únicamente me centro en la data sobre artículos.
# Los dos archivos que uso son:
# * mult.dat, que contiene los ids de las palabras más relevantes de cada artículos, y sus conteos. En total son 16980 artículos (documentos).
# * vocab.dat, el mapeo de los ids a la palabra específica. El tamaño del vocabulario usado es de 8000 palabras.
#
# La extracción del vocabulario, y demás preprocesamientos de la data son los que se explican en la sección 4 de [Wang and Blei (2011)](http://www.cs.columbia.edu/~blei/papers/WangBlei2011.pdf).
#
# Adicionalmente, en esta primera iteración del algoritmo, pido que todos los documentos tengan la misma cantidad de palabras. Eso me lleva a realizar un procesamiento extra, en el cual descarto documentos con menos de 40 palabras, quedandome con 14836. A su vez, para estos artículos, solo conservo las primeras 40 palabras, ordenadas de mayor a menor ocurrencia en el documento.
#
# A continuación, importo algunas bibliotecas que voy a usar, y realizo la carga del dataset. Por cuestiones de reproducibilidad, seteo una semilla fija.

# %%
from scipy.stats import dirichlet, multinomial, expon
from scipy.special import digamma
from collections import defaultdict
from math import pow
import numpy as np

# %%
def load_dataset():
    words_per_doc = defaultdict(list)
    with open('data/mult.dat') as keywords_f:
        words_and_counts_by_doc = []
        for l in keywords_f:
            data = l.split()
            n_words = data[0]
            if int(n_words) < 40:
                continue
            words_and_counts_by_doc.append(data[1:])
        for d, words_and_counts in enumerate(words_and_counts_by_doc):
            for w_c in words_and_counts:
                words_per_doc[d].append(tuple(w_c.split(':')))
            words_per_doc[d] = sorted(words_per_doc[d], key=lambda x: -1 *int(x[1]))[:40]
            words_per_doc[d] = [int(word) for word, _ in words_per_doc[d]]
    
    vocab = {}
    with open('data/vocab.dat') as vocab_f:
        for v, word in enumerate(vocab_f):
            vocab[v] = word.rstrip()
    
    return words_per_doc, vocab

# %%
words_by_doc, vocab = load_dataset()

# %% [markdown]
# ## LDA

# %% [markdown]
# Primero me defino algunas funciones auxiliares que me van a servir luego.

# %%
def dirich_log_expectation(alpha):
    res = None
    if len(alpha.shape) == 1:
        # Case gamma, of shape (K, )
        res = digamma(alpha) - digamma(np.sum(alpha, keepdims=True))
        return np.reshape(res, (res.shape[0], 1))
    else:
        # Case phi, of shape (K, V)
        return digamma(alpha) - digamma(np.sum(alpha, axis=1, keepdims=True))
    
def one_hot_encoding(words, length):
    '''
    Arguments:
        words: list of length N, with the positions of the desired non-zero elements
        length: the length of each encoded vector
    Output:
        A matrix of shape (N, length), where each row is a 1-hot encoding
    '''
    res = np.zeros((len(words), length))
    res[np.arange(res.shape[0]), words] = 1.0
    return res

# %% [markdown]
# La clase _LatentDirichletAllocation_ tiene como método principal _fit_, que es el que se encarga de aplicar el algoritmo propuesto por Hoffman et al. (2013). La notación elegida para los parámetros sigue fielmente la usada en la sección 3 de dicho paper.
#
# La imagen siguiente muestra el pseudocódigo del algoritmo en cuestión.

# %% [markdown]
# ![title](img/SVI-pseudocode.png)

# %%
class LatentDirichletAllocation:
        
        def __init__(self, n_topics, n_documents, words_per_doc, vocab_size, alpha, eta, words_by_doc, tau=128.0, kappa=0.7):
            np.random.seed(0)
            
            self.K = n_topics
            self.D = n_documents
            self.N = words_per_doc
            self.V = vocab_size
            self.alpha = alpha
            self.eta = eta
            self.tau = tau
            self.kappa = kappa
            
            # Initialize variational parameters
            self.lamb = []  # Parameter for words distribution by topic (qBeta ~ Dirichlet(lamb)) 
            exp_parameter = float(self.K * self.V) / (self.D * self.N)
            for k in xrange(self.K):
                self.lamb.append(expon(scale=exp_parameter).rvs(size=self.V) + self.eta) # Suggested in Hoffman et al. (2013)
            self.lamb = np.array(self.lamb)
            self.gamma = np.ones((self.D, self.K)) # Parameter for topics assignments by doc (qTheta ~ Dirichlet(gamma))
            self.phi = np.zeros((self.D, self.N, self.K))
            
            self.words_by_doc = words_by_doc
        
        def fit(self):
            #Inicializo lambda como sugiere el paper, pie de pagina 1328
            docs = self.words_by_doc.keys()
            for t in xrange(1000):
                #sample uniformly a document
                # TODO: use mini-batches
                print 'Iteracion:', t
                d = np.random.choice(docs)
                print 'Documento:', d
                ro = pow((t + self.tau), (-self.kappa))
                print 'Ro:', ro
                self.e_step(d)
                self.m_step(d, ro)
        
        def e_step(self, d):
            i = 0
            self.gamma[d] = np.random.gamma(shape=self.K, scale=1./self.K, size=self.K)
            words = self.words_by_doc[d]
            mean_change = 1.0 # Variable for determine if convergence has been achieved
            # The E-Step doesn't updates lambda parameter.
            expected_log_beta = dirich_log_expectation(self.lamb)[:, words] # shape (K, N)
            print 'expected_log_beta:', np.mean(expected_log_beta), np.std(expected_log_beta)
            print 'lambda:', np.mean(self.lamb)
            while i < 100 and mean_change > 0.001:
                if i >= 1:
                    print "ENTRE DOS VECES"
                prev_gamma = self.gamma[d]
                
                # I am leveraging vectorization over the topics and the words.
                expected_log_theta = dirich_log_expectation(self.gamma[d]) # shape (K, 1)
                
                # Updates phi[d]
                self.phi[d] = np.exp(expected_log_theta + expected_log_beta).T # shape (N, K)
                
                # Updates gamma[d]
                self.gamma[d] = self.alpha + np.sum(self.phi[d], axis=0)
                mean_change = np.mean(abs(self.gamma[d] - prev_gamma))
                i += 1
                
        def m_step(self, d, ro):
            indicator_words = one_hot_encoding(self.words_by_doc[d], self.V)
            intermediate_lambda = self.eta + self.D * np.dot(self.phi[d].T, indicator_words)
            self.lamb = (1 - ro) * self.lamb + ro * intermediate_lambda

# %%
D = len(words_by_doc)  # number of documents
N = 40 # words per doc
K = 100  # number of topics
V = len(vocab)  # vocabulary size

lda = LatentDirichletAllocation(K, D, N, V, 50.0/K, 0.1, words_by_doc)
lda.fit()
# Out:
# Iteracion: 0
# Documento: 10575
# Ro: 0.0334929207043
# expected_log_beta: -10.5443840538 2.33740537511
# lambda: 1.44942516929
# Iteracion: 1
# Documento: 953
# Ro: 0.0333109641294
# expected_log_beta: -10.5625723156 2.34246917387
# lambda: 1.4042302545
# Iteracion: 2
# Documento: 5371
# Ro: 0.0331313897449
# expected_log_beta: -10.606943944 2.3856459843
# lambda: 1.36078633903
# Iteracion: 3
# Documento: 125
# Ro: 0.0329541483957
# expected_log_beta: -10.598980056 2.37008869089
# lambda: 1.31901595469
# Iteracion: 4
# Documento: 11195
# Ro: 0.032779192306
# expected_log_beta: -10.6862854527 2.35234908501
# lambda: 1.27884554689
# Iteracion: 5
# Documento: 13945
# Ro: 0.0326064750308
# expected_log_beta: -10.6572782839 2.3602926709
# lambda: 1.24020507068
# Iteracion: 6
# Documento: 7186
# Ro: 0.0324359514088
# expected_log_beta: -10.667041601 2.38581043828
# lambda: 1.2030281801
# Iteracion: 7
# Documento: 9717
# Ro: 0.0322675775179
# expected_log_beta: -10.6679140598 2.39450492084
# lambda: 1.16725158527
# Iteracion: 8
# Documento: 4178
# Ro: 0.0321013106322
# expected_log_beta: -10.7149095126 2.37960225517
# lambda: 1.13281514425
# Iteracion: 9
# Documento: 7241
# Ro: 0.0319371091812
# expected_log_beta: -10.8024800407 2.41141952071
# lambda: 1.09966156195
# Iteracion: 10
# Documento: 6804
# Ro: 0.03177493271
# expected_log_beta: -10.8118476001 2.42001743047
# lambda: 1.0677363324
# Iteracion: 11
# Documento: 7332
# Ro: 0.0316147418418
# expected_log_beta: -10.7840513061 2.41941433238
# lambda: 1.03698765623
# Iteracion: 12
# Documento: 7768
# Ro: 0.0314564982415
# expected_log_beta: -10.8824958676 2.49480530208
# lambda: 1.00736609195
# Iteracion: 13
# Documento: 1020
# Ro: 0.0313001645812
# expected_log_beta: -10.7888349882 2.41331762956
# lambda: 0.978824586511
# Iteracion: 14
# Documento: 5040
# Ro: 0.0311457045065
# expected_log_beta: -10.8924668985 2.48827402666
# lambda: 0.951318296237
# Iteracion: 15
# Documento: 14760
# Ro: 0.0309930826047
# expected_log_beta: -10.8749853159 2.44357103274
# lambda: 0.924804399049
# Iteracion: 16
# Documento: 11482
# Ro: 0.0308422643739
# expected_log_beta: -11.0051928964 2.53653214253
# lambda: 0.899242173722
# Iteracion: 17
# Documento: 8580
# Ro: 0.0306932161937
# expected_log_beta: -11.0347741263 2.52994336585
# lambda: 0.874592712569
# Iteracion: 18
# Documento: 1086
# Ro: 0.0305459052965
# expected_log_beta: -11.0249552984 2.49540941645
# lambda: 0.850818896391
# Iteracion: 19
# Documento: 11596
# Ro: 0.0304002997402
# expected_log_beta: -11.1212054324 2.54044265177
# lambda: 0.827885377503
# Iteracion: 20
# Documento: 13281
# Ro: 0.0302563683821
# expected_log_beta: -11.0203408352 2.45990926742
# lambda: 0.80575832486
# Iteracion: 21
# Documento: 4154
# Ro: 0.0301140808538
# expected_log_beta: -11.1120365943 2.48315863899
# lambda: 0.784405549638
# Iteracion: 22
# Documento: 3714
# Ro: 0.0299734075365
# expected_log_beta: -11.1563989774 2.53941850347
# lambda: 0.763796166315
# Iteracion: 23
# Documento: 9451
# Ro: 0.0298343195382
# expected_log_beta: -11.0731758591 2.47061000037
# lambda: 0.743900783651
# Iteracion: 24
# Documento: 7600
# Ro: 0.0296967886705
# expected_log_beta: -11.1169343429 2.52664271336
# lambda: 0.7246912941
# Iteracion: 25
# Documento: 691
# Ro: 0.0295607874276
# expected_log_beta: -11.1862523361 2.53369553392
# lambda: 0.706140823882
# Iteracion: 26
# Documento: 10764
# Ro: 0.0294262889652
# expected_log_beta: -11.2882539393 2.56435890167
# lambda: 0.688223650885
# Iteracion: 27
# Documento: 5016
# Ro: 0.0292932670804
# expected_log_beta: -11.2621467502 2.4973336896
# lambda: 0.670915189163
# Iteracion: 28
# Documento: 6952
# Ro: 0.0291616961923
# expected_log_beta: -11.3127679585 2.60038984104
# lambda: 0.654191956371
# Iteracion: 29
# Documento: 12827
# Ro: 0.0290315513234
# expected_log_beta: -11.2981377305 2.50045224902
# lambda: 0.63803154466
# Iteracion: 30
# Documento: 12876
# Ro: 0.0289028080819
# expected_log_beta: -11.3540223658 2.5759070355
# lambda: 0.622412387634
# Iteracion: 31
# Documento: 13833
# Ro: 0.0287754426441
# expected_log_beta: -11.4032095235 2.55527848802
# lambda: 0.607313950617
# Iteracion: 32
# Documento: 9879
# Ro: 0.0286494317374
# expected_log_beta: -11.3786584423 2.49810848164
# lambda: 0.592716462355
# Iteracion: 33
# Documento: 12843
# Ro: 0.028524752625
# expected_log_beta: -11.4402421492 2.5623722167
# lambda: 0.578601092075
# Iteracion: 34
# Documento: 4528
# Ro: 0.0284013830896
# expected_log_beta: -11.4728979838 2.55483995236
# lambda: 0.56494979372
# Iteracion: 35
# Documento: 10660
# Ro: 0.0282793014188
# expected_log_beta: -11.4945025995 2.55267097218
# lambda: 0.551745222405
# Iteracion: 36
# Documento: 12862
# Ro: 0.0281584863904
# expected_log_beta: -11.5625214539 2.56892805141
# lambda: 0.538970834472
# Iteracion: 37
# Documento: 9125
# Ro: 0.0280389172587
# expected_log_beta: -11.5709987786 2.5743434158
# lambda: 0.526610700685
# Iteracion: 38
# Documento: 6205
# Ro: 0.0279205737406
# expected_log_beta: -11.5918567892 2.57720126225
# lambda: 0.514649620814
# Iteracion: 39
# Documento: 14469
# Ro: 0.027803436003
# expected_log_beta: -11.6409534684 2.59657867129
# lambda: 0.503072976369
# Iteracion: 40
# Documento: 11752
# Ro: 0.0276874846499
# expected_log_beta: -11.6690081173 2.56174138423
# lambda: 0.491866750807
# Iteracion: 41
# Documento: 1355
# Ro: 0.0275727007103
# expected_log_beta: -11.7234254092 2.58665879799
# lambda: 0.481017521016
# Iteracion: 42
# Documento: 1416
# Ro: 0.0274590656264
# expected_log_beta: -11.6925430222 2.56536319321
# lambda: 0.470512390565
# Iteracion: 43
# Documento: 1787
# Ro: 0.0273465612426
# expected_log_beta: -11.781859074 2.59698372303
# lambda: 0.460339017679
# Iteracion: 44
# Documento: 2909
# Ro: 0.0272351697938
# expected_log_beta: -11.7427150867 2.56784741614
# lambda: 0.450485502609
# Iteracion: 45
# Documento: 13343
# Ro: 0.0271248738954
# expected_log_beta: -11.8545090305 2.59741334108
# lambda: 0.440940508678
# Iteracion: 46
# Documento: 3005
# Ro: 0.0270156565329
# expected_log_beta: -11.9469298173 2.60204127838
# lambda: 0.431693027389
# Iteracion: 47
# Documento: 2310
# Ro: 0.0269075010515
# expected_log_beta: -11.901751923 2.60280765508
# lambda: 0.422732591641
# Iteracion: 48
# Documento: 3198
# Ro: 0.0268003911472
# expected_log_beta: -11.9650708542 2.60542972645
# lambda: 0.414049136771
# Iteracion: 49
# Documento: 10208
# Ro: 0.0266943108569
# expected_log_beta: -12.0080324145 2.60259929862
# lambda: 0.405632949488
# Iteracion: 50
# Documento: 8410
# Ro: 0.0265892445496
# expected_log_beta: -12.0329850661 2.56605954457
# lambda: 0.397474737053
# Iteracion: 51
# Documento: 13992
# Ro: 0.0264851769177
# expected_log_beta: -12.0835651655 2.61306769807
# lambda: 0.389565530282
# Iteracion: 52
# Documento: 9260
# Ro: 0.0263820929685
# expected_log_beta: -12.0761695434 2.58828590093
# lambda: 0.38189675534
# Iteracion: 53
# Documento: 2353
# Ro: 0.0262799780163
# expected_log_beta: -12.1514361325 2.5915762755
# lambda: 0.374460144445
# Iteracion: 54
# Documento: 12682
# Ro: 0.0261788176737
# expected_log_beta: -12.1707336286 2.57756255021
# lambda: 0.367247741312
# Iteracion: 55
# Documento: 19
# Ro: 0.0260785978448
# expected_log_beta: -12.1937941036 2.54031928947
# lambda: 0.360251896528
# Iteracion: 56
# Documento: 6545
# Ro: 0.0259793047173
# expected_log_beta: -12.1990380595 2.57984297023
# lambda: 0.353465248407
# Iteracion: 57
# Documento: 1691
# Ro: 0.0258809247554
# expected_log_beta: -12.2829813307 2.64233772438
# lambda: 0.346880767687
# Iteracion: 58
# Documento: 6180
# Ro: 0.0257834446926
# expected_log_beta: -12.2604516531 2.54534865113
# lambda: 0.340491642103
# Iteracion: 59
# Documento: 14356
# Ro: 0.0256868515254
# expected_log_beta: -12.3527466475 2.57190165354
# lambda: 0.334291286103
# Iteracion: 60
# Documento: 5143
# Ro: 0.0255911325061
# expected_log_beta: -12.4192858454 2.58827223605
# lambda: 0.328273410506
# Iteracion: 61
# Documento: 14184
# Ro: 0.0254962751371
# expected_log_beta: -12.3774564666 2.55704028957
# lambda: 0.32243195923
# Iteracion: 62
# Documento: 14125
# Ro: 0.0254022671641
# expected_log_beta: -12.4908294837 2.57675385926
# lambda: 0.316761087352
# Iteracion: 63
# Documento: 5886
# Ro: 0.0253090965704
# expected_log_beta: -12.5030914603 2.58812580041
# lambda: 0.311255157149
# Iteracion: 64
# Documento: 922
# Ro: 0.0252167515712
# expected_log_beta: -12.5797742829 2.55967994302
# lambda: 0.305908777538
# Iteracion: 65
# Documento: 9390
# Ro: 0.0251252206078
# expected_log_beta: -12.540539239 2.55115189775
# lambda: 0.30071670175
# Iteracion: 66
# Documento: 1636
# Ro: 0.0250344923418
# expected_log_beta: -12.620195971 2.53836180849
# lambda: 0.295673930795
# Iteracion: 67
# Documento: 12107
# Ro: 0.0249445556506
# expected_log_beta: -12.6164689084 2.55113964827
# lambda: 0.290775592159
# Iteracion: 68
# Documento: 3536
# Ro: 0.0248553996213
# expected_log_beta: -12.7452186937 2.5499297034
# lambda: 0.286017042187
# Iteracion: 69
# Documento: 6017
# Ro: 0.0247670135463
# expected_log_beta: -12.7381043545 2.57115161665
# lambda: 0.281393762717
# Iteracion: 70
# Documento: 1239
# Ro: 0.0246793869184
# expected_log_beta: -12.7745659449 2.48146548299
# lambda: 0.276901420472
# Iteracion: 71
# Documento: 3783
# Ro: 0.0245925094256
# expected_log_beta: -12.8341832491 2.51706736388
# lambda: 0.272535820011
# Iteracion: 72
# Documento: 3406
# Ro: 0.024506370947
# expected_log_beta: -12.7966411322 2.48426767179
# lambda: 0.268292944867
# Iteracion: 73
# Documento: 1243
# Ro: 0.0244209615481
# expected_log_beta: -12.8954295272 2.50359282786
# lambda: 0.264168908701
# Iteracion: 74
# Documento: 1097
# Ro: 0.0243362714765
# expected_log_beta: -12.9242889667 2.49376571195
# lambda: 0.260159953572
# Iteracion: 75
# Documento: 8408
# Ro: 0.0242522911578
# expected_log_beta: -12.9350501573 2.53500328928
# lambda: 0.25626245617
# Iteracion: 76
# Documento: 6966
# Ro: 0.0241690111911
# expected_log_beta: -13.0129693186 2.47174222437
# lambda: 0.252472931506
# Iteracion: 77
# Documento: 4878
# Ro: 0.0240864223456
# expected_log_beta: -13.0472065619 2.48628176053
# lambda: 0.248787990549
# Iteracion: 78
# Documento: 11918
# Ro: 0.0240045155563
# expected_log_beta: -13.0394947094 2.46268414923
# lambda: 0.245204397395
# Iteracion: 79
# Documento: 7665
# Ro: 0.0239232819203
# expected_log_beta: -13.0822529781 2.46930081786
# lambda: 0.241719012263
# Iteracion: 80
# Documento: 6367
# Ro: 0.0238427126932
# expected_log_beta: -13.1429585842 2.45606110344
# lambda: 0.238328802117
# Iteracion: 81
# Documento: 5874
# Ro: 0.0237627992856
# expected_log_beta: -13.1450569047 2.42710643276
# lambda: 0.235030829824
# Iteracion: 82
# Documento: 4226
# Ro: 0.0236835332595
# expected_log_beta: -13.2739298266 2.42458451061
# lambda: 0.231822276526
# Iteracion: 83
# Documento: 10708
# Ro: 0.0236049063249
# expected_log_beta: -13.2074043556 2.43124978299
# lambda: 0.228700400843
# Iteracion: 84
# Documento: 7779
# Ro: 0.0235269103367
# expected_log_beta: -13.2769150644 2.41658325635
# lambda: 0.22566258408
# Iteracion: 85
# Documento: 9565
# Ro: 0.0234495372914
# expected_log_beta: -13.3865133572 2.39544588658
# lambda: 0.222706271141
# Iteracion: 86
# Documento: 12236
# Ro: 0.0233727793237
# expected_log_beta: -13.3654889 2.4095663993
# lambda: 0.219828995078
# Iteracion: 87
# Documento: 7119
# Ro: 0.0232966287041
# expected_log_beta: -13.3680626616 2.35109982803
# lambda: 0.217028381695
# Iteracion: 88
# Documento: 1216
# Ro: 0.0232210778355
# expected_log_beta: -13.4037046197 2.36198440337
# lambda: 0.214302133984
# Iteracion: 89
# Documento: 4350
# Ro: 0.0231461192503
# expected_log_beta: -13.4557914706 2.36176601416
# lambda: 0.211648034212
# Iteracion: 90
# Documento: 1570
# Ro: 0.0230717456079
# expected_log_beta: -13.5204680934 2.32948151102
# lambda: 0.209063929842
# Iteracion: 91
# Documento: 13494
# Ro: 0.0229979496916
# expected_log_beta: -13.5271568852 2.33266075277
# lambda: 0.206547737852
# Iteracion: 92
# Documento: 6172
# Ro: 0.0229247244063
# expected_log_beta: -13.548593347 2.33956312063
# lambda: 0.20409746375
# Iteracion: 93
# Documento: 4489
# Ro: 0.0228520627758
# expected_log_beta: -13.6130248923 2.31282054427
# lambda: 0.201711160504
# Iteracion: 94
# Documento: 12248
# Ro: 0.0227799579402
# expected_log_beta: -13.6937183907 2.269142094
# lambda: 0.199386943806
# Iteracion: 95
# Documento: 9150
# Ro: 0.0227084031535
# expected_log_beta: -13.7186071349 2.27944082103
# lambda: 0.197122997738
# Iteracion: 96
# Documento: 8964
# Ro: 0.0226373917811
# expected_log_beta: -13.6881154206 2.29219539015
# lambda: 0.194917573137
# Iteracion: 97
# Documento: 6339
# Ro: 0.0225669172977
# expected_log_beta: -13.7863993832 2.25289104304
# lambda: 0.19276897467
# Iteracion: 98
# Documento: 10938
# Ro: 0.0224969732849
# expected_log_beta: -13.8197318602 2.21859844729
# lambda: 0.19067554128
# Iteracion: 99
# Documento: 3983
# Ro: 0.022427553429
# expected_log_beta: -13.7859244258 2.25641288728
# lambda: 0.188635687172
# Iteracion: 100
# Documento: 11831
# Ro: 0.0223586515186
# expected_log_beta: -13.8252236552 2.23038038961
# lambda: 0.186647880708
# Iteracion: 101
# Documento: 2406
# Ro: 0.0222902614431
# expected_log_beta: -13.8243700655 2.21602892694
# lambda: 0.184710620629
# Iteracion: 102
# Documento: 13383
# Ro: 0.02222237719
# expected_log_beta: -13.9171677617 2.23422242646
# lambda: 0.182822469411
# Iteracion: 103
# Documento: 7211
# Ro: 0.0221549928432
# expected_log_beta: -13.9683654194 2.19187015704
# lambda: 0.18098202519
# Iteracion: 104
# Documento: 6552
# Ro: 0.0220881025811
# expected_log_beta: -13.9683863501 2.16902118628
# lambda: 0.17918793066
# Iteracion: 105
# Documento: 2011
# Ro: 0.0220217006745
# expected_log_beta: -14.0753746447 2.17723602653
# lambda: 0.177438876938
# Iteracion: 106
# Documento: 11691
# Ro: 0.021955781485
# expected_log_beta: -14.0558580498 2.12092119351
# lambda: 0.175733598984
# Iteracion: 107
# Documento: 1847
# Ro: 0.0218903394628
# expected_log_beta: -14.0983560966 2.13184974225
# lambda: 0.174070857358
# Iteracion: 108
# Documento: 6740
# Ro: 0.0218253691455
# expected_log_beta: -14.1619957929 2.14983730172
# lambda: 0.172449471176
# Iteracion: 109
# Documento: 10770
# Ro: 0.0217608651556
# expected_log_beta: -14.2160242279 2.10782605096
# lambda: 0.170868284857
# Iteracion: 110
# Documento: 4484
# Ro: 0.0216968221997
# expected_log_beta: -14.155161907 2.11653738144
# lambda: 0.169326176981
# Iteracion: 111
# Documento: 6927
# Ro: 0.021633235066
# expected_log_beta: -14.2312986963 2.08213292882
# lambda: 0.167822066876
# Iteracion: 112
# Documento: 7728
# Ro: 0.0215700986235
# expected_log_beta: -14.3087769636 2.05952962832
# lambda: 0.166354900996
# Iteracion: 113
# Documento: 13845
# Ro: 0.0215074078196
# expected_log_beta: -14.2877363809 2.03655073635
# lambda: 0.164923658281
# Iteracion: 114
# Documento: 464
# Ro: 0.0214451576793
# expected_log_beta: -14.3632462251 2.02713208491
# lambda: 0.163527357988
# Iteracion: 115
# Documento: 8154
# Ro: 0.0213833433033
# expected_log_beta: -14.3344924589 2.02822074036
# lambda: 0.162165040721
# Iteracion: 116
# Documento: 8166
# Ro: 0.0213219598667
# expected_log_beta: -14.3385059869 2.00473734752
# lambda: 0.160835780664
# Iteracion: 117
# Documento: 11563
# Ro: 0.0212610026173
# expected_log_beta: -14.4237942614 1.95732143876
# lambda: 0.159538677694
# Iteracion: 118
# Documento: 2405
# Ro: 0.0212004668748
# expected_log_beta: -14.4380374777 1.99301355679
# lambda: 0.15827285659
# Iteracion: 119
# Documento: 324
# Ro: 0.0211403480286
# expected_log_beta: -14.4734955629 1.96131886918
# lambda: 0.157037477285
# Iteracion: 120
# Documento: 8191
# Ro: 0.0210806415373
# expected_log_beta: -14.5047994348 1.95665978116
# lambda: 0.155831715206
# Iteracion: 121
# Documento: 3868
# Ro: 0.0210213429268
# expected_log_beta: -14.4989448462 1.94537398657
# lambda: 0.15465477643
# Iteracion: 122
# Documento: 9971
# Ro: 0.0209624477894
# expected_log_beta: -14.5217064555 1.92439130823
# lambda: 0.153505888123
# Iteracion: 123
# Documento: 7852
# Ro: 0.0209039517823
# expected_log_beta: -14.6629549439 1.8956895725
# lambda: 0.152384299202
# Iteracion: 124
# Documento: 2377
# Ro: 0.0208458506266
# expected_log_beta: -14.6618674452 1.87987322782
# lambda: 0.151289284613
# Iteracion: 125
# Documento: 6054
# Ro: 0.0207881401059
# expected_log_beta: -14.7378533621 1.84340133928
# lambda: 0.150220138931
# Iteracion: 126
# Documento: 9456
# Ro: 0.0207308160654
# expected_log_beta: -14.7163685207 1.83970587603
# lambda: 0.149176177025
# Iteracion: 127
# Documento: 3034
# Ro: 0.0206738744105
# expected_log_beta: -14.7441057117 1.81918312273
# lambda: 0.148156735179
# Iteracion: 128
# Documento: 1519
# Ro: 0.0206173111058
# expected_log_beta: -14.7837555539 1.81482169236
# lambda: 0.147161168618
# Iteracion: 129
# Documento: 5195
# Ro: 0.0205611221742
# expected_log_beta: -14.8113782939 1.80293071989
# lambda: 0.146188851194
# Iteracion: 130
# Documento: 13245
# Ro: 0.0205053036955
# expected_log_beta: -14.8147207728 1.79983890677
# lambda: 0.145239173915
# Iteracion: 131
# Documento: 6390
# Ro: 0.0204498518056
# expected_log_beta: -14.8259972479 1.79492921751
# lambda: 0.144311548692
# Iteracion: 132
# Documento: 12199
# Ro: 0.0203947626954
# expected_log_beta: -14.9045071152 1.77926070824
# lambda: 0.143405401888
# Iteracion: 133
# Documento: 12419
# Ro: 0.0203400326098
# expected_log_beta: -14.8907976962 1.73100037647
# lambda: 0.14252017551
# Iteracion: 134
# Documento: 6995
# Ro: 0.0202856578469
# expected_log_beta: -14.9313176577 1.75379889027
# lambda: 0.141655329031
# Iteracion: 135
# Documento: 1671
# Ro: 0.0202316347568
# expected_log_beta: -14.9704638436 1.72053388359
# lambda: 0.140810338969
# Iteracion: 136
# Documento: 9352
# Ro: 0.0201779597408
# expected_log_beta: -14.9689542431 1.69343274879
# lambda: 0.139984693744
# Iteracion: 137
# Documento: 3077
# Ro: 0.0201246292503
# expected_log_beta: -14.9733293931 1.68631600492
# lambda: 0.139177896602
# Iteracion: 138
# Documento: 6733
# Ro: 0.0200716397865
# expected_log_beta: -15.0534177806 1.66639881847
# lambda: 0.13838946884
# Iteracion: 139
# Documento: 8513
# Ro: 0.0200189878988
# expected_log_beta: -15.0319112256 1.66891657427
# lambda: 0.137618940969
# Iteracion: 140
# Documento: 730
# Ro: 0.0199666701842
# expected_log_beta: -15.069698914 1.63401392658
# lambda: 0.136865859594
# Iteracion: 141
# Documento: 8750
# Ro: 0.0199146832868
# expected_log_beta: -15.0903762399 1.64088714442
# lambda: 0.136129781625
# Iteracion: 142
# Documento: 7186
# Ro: 0.0198630238966
# expected_log_beta: -15.115877456 1.62455383943
# lambda: 0.135410279169
# Iteracion: 143
# Documento: 10065
# Ro: 0.0198116887488
# expected_log_beta: -15.1281027485 1.60252972579
# lambda: 0.13470693456
# Iteracion: 144
# Documento: 13976
# Ro: 0.019760674623
# expected_log_beta: -15.1376079721 1.58230547128
# lambda: 0.134019341976
# Iteracion: 145
# Documento: 6465
# Ro: 0.0197099783424
# expected_log_beta: -15.2294874682 1.57602484191
# lambda: 0.13334710652
# Iteracion: 146
# Documento: 7653
# Ro: 0.0196595967734
# expected_log_beta: -15.2213787378 1.56310500245
# lambda: 0.132689845012
# Iteracion: 147
# Documento: 12590
# Ro: 0.0196095268244
# expected_log_beta: -15.2583619159 1.53305731381
# lambda: 0.132047184834
# Iteracion: 148
# Documento: 9863
# Ro: 0.0195597654452
# expected_log_beta: -15.2886779566 1.51471986247
# lambda: 0.13141876297
# Iteracion: 149
# Documento: 8588
# Ro: 0.0195103096265
# expected_log_beta: -15.2645791493 1.51472699355
# lambda: 0.130804227056
# Iteracion: 150
# Documento: 1840
# Ro: 0.0194611563989
# expected_log_beta: -15.3265344247 1.48365873106
# lambda: 0.130203234953
# Iteracion: 151
# Documento: 542
# Ro: 0.0194123028327
# expected_log_beta: -15.3394263903 1.51298393224
# lambda: 0.129615452215
# Iteracion: 152
# Documento: 1010
# Ro: 0.0193637460367
# expected_log_beta: -15.4017469488 1.43804222799
# lambda: 0.129040555632
# Iteracion: 153
# Documento: 9597
# Ro: 0.0193154831578
# expected_log_beta: -15.3903247747 1.4472705052
# lambda: 0.128478227642
# Iteracion: 154
# Documento: 5039
# Ro: 0.0192675113805
# expected_log_beta: -15.4022691041 1.42503076294
# lambda: 0.127928163164
# Iteracion: 155
# Documento: 9631
# Ro: 0.0192198279258
# expected_log_beta: -15.4590786742 1.40160937478
# lambda: 0.12739006264
# Iteracion: 156
# Documento: 1979
# Ro: 0.0191724300514
# expected_log_beta: -15.4819646231 1.39504680451
# lambda: 0.126863635582
# Iteracion: 157
# Documento: 7700
# Ro: 0.0191253150503
# expected_log_beta: -15.4943999915 1.38720518262
# lambda: 0.126348599556
# Iteracion: 158
# Documento: 6025
# Ro: 0.0190784802505
# expected_log_beta: -15.4975960964 1.35482912609
# lambda: 0.125844679549
# Iteracion: 159
# Documento: 13880
# Ro: 0.0190319230148
# expected_log_beta: -15.5456204634 1.36378615125
# lambda: 0.125351607042
# Iteracion: 160
# Documento: 6583
# Ro: 0.0189856407394
# expected_log_beta: -15.5626201527 1.35028514096
# lambda: 0.124869122289
# Iteracion: 161
# Documento: 1862
# Ro: 0.0189396308544
# expected_log_beta: -15.5805853709 1.33336598328
# lambda: 0.124396970456
# Iteracion: 162
# Documento: 1126
# Ro: 0.0188938908223
# expected_log_beta: -15.6152082087 1.30077587793
# lambda: 0.123934905108
# Iteracion: 163
# Documento: 7584
# Ro: 0.018848418138
# expected_log_beta: -15.60851418 1.28467831
# lambda: 0.12348268581
# Iteracion: 164
# Documento: 12086
# Ro: 0.0188032103282
# expected_log_beta: -15.6415311966 1.27240430405
# lambda: 0.12304007812
# Iteracion: 165
# Documento: 8047
# Ro: 0.0187582649508
# expected_log_beta: -15.6355689453 1.28049779033
# lambda: 0.122606854342
# Iteracion: 166
# Documento: 14063
# Ro: 0.0187135795946
# expected_log_beta: -15.7161089537 1.23486311008
# lambda: 0.122182792788
# Iteracion: 167
# Documento: 5202
# Ro: 0.0186691518783
# expected_log_beta: -15.6903861931 1.26576022247
# lambda: 0.121767676667
# Iteracion: 168
# Documento: 3865
# Ro: 0.0186249794509
# expected_log_beta: -15.7005418665 1.23473808729
# lambda: 0.121361296263
# Iteracion: 169
# Documento: 11085
# Ro: 0.0185810599901
# expected_log_beta: -15.7279683708 1.22198167543
# lambda: 0.120963445814
# Iteracion: 170
# Documento: 11418
# Ro: 0.0185373912031
# expected_log_beta: -15.7732653571 1.19549696058
# lambda: 0.12057392582
# Iteracion: 171
# Documento: 11736
# Ro: 0.0184939708249
# expected_log_beta: -15.7397535861 1.21104180586
# lambda: 0.120192541862
# Iteracion: 172
# Documento: 8545
# Ro: 0.0184507966188
# expected_log_beta: -15.7644575814 1.19846284431
# lambda: 0.119819104619
# Iteracion: 173
# Documento: 12387
# Ro: 0.0184078663754
# expected_log_beta: -15.8259537415 1.14135564827
# lambda: 0.11945342936
# Iteracion: 174
# Documento: 11744
# Ro: 0.0183651779127
# expected_log_beta: -15.8172877837 1.15900640405
# lambda: 0.119095335776
# Iteracion: 175
# Documento: 14296
# Ro: 0.018322729075
# expected_log_beta: -15.8634302472 1.14344310222
# lambda: 0.118744649116
# Iteracion: 176
# Documento: 9957
# Ro: 0.018280517733
# expected_log_beta: -15.8492344073 1.13991052684
# lambda: 0.11840119846
# Iteracion: 177
# Documento: 12154
# Ro: 0.0182385417833
# expected_log_beta: -15.8858635968 1.12156148311
# lambda: 0.118064817476
# Iteracion: 178
# Documento: 13504
# Ro: 0.0181967991478
# expected_log_beta: -15.8852017285 1.12635214185
# lambda: 0.117735343856
# Iteracion: 179
# Documento: 9451
# Ro: 0.0181552877736
# expected_log_beta: -15.8995792442 1.07593796464
# lambda: 0.117412619649
# Iteracion: 180
# Documento: 8519
# Ro: 0.0181140056325
# expected_log_beta: -15.9483141501 1.05733389974
# lambda: 0.11709649071
# Iteracion: 181
# Documento: 10914
# Ro: 0.0180729507204
# expected_log_beta: -15.9669240596 1.05348304989
# lambda: 0.116786806719
# Iteracion: 182
# Documento: 1460
# Ro: 0.0180321210573
# expected_log_beta: -15.9425444762 1.06258238623
# lambda: 0.116483421509
# Iteracion: 183
# Documento: 1600
# Ro: 0.0179915146867
# expected_log_beta: -15.9471456143 1.04254531048
# lambda: 0.116186192459
# Iteracion: 184
# Documento: 13430
# Ro: 0.0179511296754
# expected_log_beta: -15.9801384798 1.03778543165
# lambda: 0.115894980258
# Iteracion: 185
# Documento: 12365
# Ro: 0.0179109641129
# expected_log_beta: -16.0168484974 1.01069423932
# lambda: 0.115609649277
# Iteracion: 186
# Documento: 7294
# Ro: 0.0178710161113
# expected_log_beta: -16.0360806791 0.987241640313
# lambda: 0.11533006712
# Iteracion: 187
# Documento: 11263
# Ro: 0.017831283805
# expected_log_beta: -16.0364107705 1.00918315059
# lambda: 0.11505610485
# Iteracion: 188
# Documento: 8098
# Ro: 0.01779176535
# expected_log_beta: -16.0229580122 0.981374008589
# lambda: 0.114787636846
# Iteracion: 189
# Documento: 9244
# Ro: 0.0177524589242
# expected_log_beta: -16.0740169438 0.975630850795
# lambda: 0.114524540263
# Iteracion: 190
# Documento: 11424
# Ro: 0.0177133627264
# expected_log_beta: -16.1031378572 0.935613563505
# lambda: 0.11426669552
# Iteracion: 191
# Documento: 13184
# Ro: 0.0176744749763
# expected_log_beta: -16.1044608216 0.945186272314
# lambda: 0.114013985776
# Iteracion: 192
# Documento: 3198
# Ro: 0.0176357939145
# expected_log_beta: -16.1169746579 0.925408762824
# lambda: 0.113766297374
# Iteracion: 193
# Documento: 6810
# Ro: 0.0175973178015
# expected_log_beta: -16.1338173237 0.913411239523
# lambda: 0.113523519155
# Iteracion: 194
# Documento: 10947
# Ro: 0.0175590449182
# expected_log_beta: -16.1336171149 0.904433219906
# lambda: 0.113285542806
# Iteracion: 195
# Documento: 11617
# Ro: 0.0175209735647
# expected_log_beta: -16.1379847936 0.926486341079
# lambda: 0.113052262624
# Iteracion: 196
# Documento: 13837
# Ro: 0.017483102061
# expected_log_beta: -16.1929982905 0.875438727481
# lambda: 0.11282357561
# Iteracion: 197
# Documento: 10044
# Ro: 0.017445428746
# expected_log_beta: -16.1862285719 0.86187611028
# lambda: 0.112599380902
# Iteracion: 198
# Documento: 7909
# Ro: 0.0174079519775
# expected_log_beta: -16.1866526716 0.883015564497
# lambda: 0.11237958044
# Iteracion: 199
# Documento: 9155
# Ro: 0.0173706701319
# expected_log_beta: -16.1933531816 0.877417835127
# lambda: 0.112164078506
# Iteracion: 200
# Documento: 11761
# Ro: 0.0173335816039
# expected_log_beta: -16.2331548401 0.832397637748
# lambda: 0.111952781473
# Iteracion: 201
# Documento: 7588
# Ro: 0.0172966848063
# expected_log_beta: -16.2156349787 0.861641921934
# lambda: 0.111745598006
# Iteracion: 202
# Documento: 10348
# Ro: 0.0172599781696
# expected_log_beta: -16.2746924545 0.801728267181
# lambda: 0.111542439196
# Iteracion: 203
# Documento: 5427
# Ro: 0.0172234601421
# expected_log_beta: -16.2719535153 0.79450263826
# lambda: 0.111343217908
# Iteracion: 204
# Documento: 5526
# Ro: 0.0171871291891
# expected_log_beta: -16.2879473013 0.803621840973
# lambda: 0.111147849401
# Iteracion: 205
# Documento: 7496
# Ro: 0.0171509837931
# expected_log_beta: -16.2824994678 0.801600156753
# lambda: 0.110956250829
# Iteracion: 206
# Documento: 2087
# Ro: 0.0171150224535
# expected_log_beta: -16.2883037242 0.803865736159
# lambda: 0.110768341321
# Iteracion: 207
# Documento: 3230
# Ro: 0.0170792436861
# expected_log_beta: -16.3068911743 0.75978155214
# lambda: 0.110584041888
# Iteracion: 208
# Documento: 516
# Ro: 0.0170436460231
# expected_log_beta: -16.3330036843 0.762946467016
# lambda: 0.110403275337
# Iteracion: 209
# Documento: 8935
# Ro: 0.0170082280131
# expected_log_beta: -16.3121020777 0.762062824634
# lambda: 0.110225966489
# Iteracion: 210
# Documento: 13169
# Ro: 0.0169729882201
# expected_log_beta: -16.3501523557 0.752980716676
# lambda: 0.110052041798
# Iteracion: 211
# Documento: 4029
# Ro: 0.0169379252243
# expected_log_beta: -16.3541054952 0.757592360502
# lambda: 0.109881429462
# Iteracion: 212
# Documento: 11130
# Ro: 0.0169030376208
# expected_log_beta: -16.3775234575 0.715290640471
# lambda: 0.109714059411
# Iteracion: 213
# Documento: 3234
# Ro: 0.0168683240205
# expected_log_beta: -16.3705962154 0.712801698232
# lambda: 0.109549863095
# Iteracion: 214
# Documento: 9334
# Ro: 0.016833783049
# expected_log_beta: -16.3750217074 0.708918130981
# lambda: 0.109388773699
# Iteracion: 215
# Documento: 4526
# Ro: 0.0167994133468
# expected_log_beta: -16.4200287021 0.67477176203
# lambda: 0.10923072587
# Iteracion: 216
# Documento: 2922
# Ro: 0.0167652135691
# expected_log_beta: -16.393442464 0.688927171656
# lambda: 0.109075655808
# Iteracion: 217
# Documento: 3936
# Ro: 0.0167311823854
# expected_log_beta: -16.4190091162 0.684878950378
# lambda: 0.108923501242
# Iteracion: 218
# Documento: 344
# Ro: 0.0166973184795
# expected_log_beta: -16.4122004533 0.68874163631
# lambda: 0.108774201237
# Iteracion: 219
# Documento: 10629
# Ro: 0.0166636205494
# expected_log_beta: -16.4316689163 0.673468065892
# lambda: 0.10862769634
# Iteracion: 220
# Documento: 2065
# Ro: 0.0166300873067
# expected_log_beta: -16.4292778994 0.672702481185
# lambda: 0.108483928382
# Iteracion: 221
# Documento: 7094
# Ro: 0.0165967174767
# expected_log_beta: -16.4531870571 0.640529202637
# lambda: 0.108342840617
# Iteracion: 222
# Documento: 275
# Ro: 0.0165635097983
# expected_log_beta: -16.4629926479 0.628682740807
# lambda: 0.108204377516
# Iteracion: 223
# Documento: 14673
# Ro: 0.0165304630237
# expected_log_beta: -16.4637139145 0.63754962509
# lambda: 0.108068484871
# Iteracion: 224
# Documento: 3196
# Ro: 0.0164975759182
# expected_log_beta: -16.4782276235 0.623493703019
# lambda: 0.107935109722
# Iteracion: 225
# Documento: 7506
# Ro: 0.0164648472599
# expected_log_beta: -16.4670769137 0.625875028987
# lambda: 0.107804200275
# Iteracion: 226
# Documento: 10879
# Ro: 0.0164322758398
# expected_log_beta: -16.4921120416 0.607824986062
# lambda: 0.107675705942
# Iteracion: 227
# Documento: 3155
# Ro: 0.0163998604615
# expected_log_beta: -16.5010580383 0.608664872919
# lambda: 0.107549577233
# Iteracion: 228
# Documento: 9336
# Ro: 0.0163675999411
# expected_log_beta: -16.5169949621 0.584647640787
# lambda: 0.107425765826
# Iteracion: 229
# Documento: 8268
# Ro: 0.0163354931069
# expected_log_beta: -16.5246469042 0.582859219246
# lambda: 0.107304224439
# Iteracion: 230
# Documento: 398
# Ro: 0.0163035387993
# expected_log_beta: -16.5387489249 0.569171461204
# lambda: 0.107184906904
# Iteracion: 231
# Documento: 11561
# Ro: 0.0162717358707
# expected_log_beta: -16.5481771622 0.569531133577
# lambda: 0.10706776806
# Iteracion: 232
# Documento: 2545
# Ro: 0.0162400831853
# expected_log_beta: -16.5459626938 0.563660262206
# lambda: 0.106952763758
# Iteracion: 233
# Documento: 7011
# Ro: 0.0162085796189
# expected_log_beta: -16.5588381559 0.556806179465
# lambda: 0.106839850845
# Iteracion: 234
# Documento: 4038
# Ro: 0.0161772240588
# expected_log_beta: -16.5521855988 0.551725432073
# lambda: 0.106728987117
# Iteracion: 235
# Documento: 5713
# Ro: 0.0161460154037
# expected_log_beta: -16.5970811776 0.530295122945
# lambda: 0.106620131319
# Iteracion: 236
# Documento: 1062
# Ro: 0.0161149525635
# expected_log_beta: -16.5824449235 0.540282632564
# lambda: 0.106513243076
# Iteracion: 237
# Documento: 1765
# Ro: 0.016084034459
# expected_log_beta: -16.5801321981 0.531358274174
# lambda: 0.106408282994
# Iteracion: 238
# Documento: 3599
# Ro: 0.0160532600222
# expected_log_beta: -16.5904330137 0.52733236395
# lambda: 0.106305212458
# Iteracion: 239
# Documento: 1405
# Ro: 0.0160226281957
# expected_log_beta: -16.6010975636 0.509365160638
# lambda: 0.106203993749
# Iteracion: 240
# Documento: 7545
# Ro: 0.0159921379326
# expected_log_beta: -16.597458823 0.516040624654
# lambda: 0.106104589955
# Iteracion: 241
# Documento: 13617
# Ro: 0.0159617881968
# expected_log_beta: -16.6151206099 0.500194482715
# lambda: 0.106006965001
# Iteracion: 242
# Documento: 3789
# Ro: 0.0159315779624
# expected_log_beta: -16.6254011907 0.493108410534
# lambda: 0.105911083578
# Iteracion: 243
# Documento: 14393
# Ro: 0.0159015062136
# expected_log_beta: -16.6253226483 0.490767519855
# lambda: 0.105816911165
# Iteracion: 244
# Documento: 14049
# Ro: 0.015871571945
# expected_log_beta: -16.6340407964 0.477801676449
# lambda: 0.105724413989
# Iteracion: 245
# Documento: 6021
# Ro: 0.0158417741611
# expected_log_beta: -16.6424803623 0.474732375205
# lambda: 0.105633558996
# Iteracion: 246
# Documento: 4822
# Ro: 0.0158121118759
# expected_log_beta: -16.6491439979 0.468063310941
# lambda: 0.105544313877
# Iteracion: 247
# Documento: 5857
# Ro: 0.0157825841137
# expected_log_beta: -16.652085331 0.467432072121
# lambda: 0.105456647009
# Iteracion: 248
# Documento: 1746
# Ro: 0.0157531899081
# expected_log_beta: -16.6564868696 0.452541220548
# lambda: 0.10537052747
# Iteracion: 249
# Documento: 1063
# Ro: 0.015723928302
# expected_log_beta: -16.6722255187 0.449604167073
# lambda: 0.105285924972
# Iteracion: 250
# Documento: 629
# Ro: 0.0156947983481
# expected_log_beta: -16.673902596 0.443118847657
# lambda: 0.1052028099
# Iteracion: 251
# Documento: 14111
# Ro: 0.015665799108
# expected_log_beta: -16.6858134044 0.438339021981
# lambda: 0.105121153275
# Iteracion: 252
# Documento: 10432
# Ro: 0.0156369296527
# expected_log_beta: -16.6998728274 0.428636480231
# lambda: 0.105040926744
# Iteracion: 253
# Documento: 11361
# Ro: 0.015608189062
# expected_log_beta: -16.694966083 0.425923554325
# lambda: 0.104962102543
# Iteracion: 254
# Documento: 5108
# Ro: 0.0155795764247
# expected_log_beta: -16.6956059863 0.425731163778
# lambda: 0.104884653522
# Iteracion: 255
# Documento: 990
# Ro: 0.0155510908386
# expected_log_beta: -16.7041327283 0.417871297746
# lambda: 0.104808553101
# Iteracion: 256
# Documento: 12376
# Ro: 0.0155227314098
# expected_log_beta: -16.7168118184 0.395411785201
# lambda: 0.10473377526
# Iteracion: 257
# Documento: 11026
# Ro: 0.0154944972534
# expected_log_beta: -16.7120474441 0.404075071012
# lambda: 0.104660294537
# Iteracion: 258
# Documento: 1230
# Ro: 0.0154663874926
# expected_log_beta: -16.7199863338 0.410188029937
# lambda: 0.104588086016
# Iteracion: 259
# Documento: 5955
# Ro: 0.0154384012594
# expected_log_beta: -16.7240773087 0.391418602396
# lambda: 0.104517125296
# Iteracion: 260
# Documento: 11788
# Ro: 0.0154105376938
# expected_log_beta: -16.7339024677 0.387678154016
# lambda: 0.104447388493
# Iteracion: 261
# Documento: 14282
# Ro: 0.0153827959439
# expected_log_beta: -16.7371104513 0.382481367574
# lambda: 0.104378852226
# Iteracion: 262
# Documento: 7357
# Ro: 0.0153551751663
# expected_log_beta: -16.7475984677 0.3727543877
# lambda: 0.104311493615
# Iteracion: 263
# Documento: 10173
# Ro: 0.0153276745251
# expected_log_beta: -16.7562343848 0.375427596783
# lambda: 0.104245290248
# Iteracion: 264
# Documento: 13117
# Ro: 0.0153002931926
# expected_log_beta: -16.7662828715 0.366276654734
# lambda: 0.104180220191
# Iteracion: 265
# Documento: 11322
# Ro: 0.0152730303488
# expected_log_beta: -16.7639115911 0.357335640581
# lambda: 0.104116261961
# Iteracion: 266
# Documento: 8578
# Ro: 0.0152458851814
# expected_log_beta: -16.7769717178 0.346727933375
# lambda: 0.104053394531
# Iteracion: 267
# Documento: 6513
# Ro: 0.0152188568857
# expected_log_beta: -16.7739297064 0.353982457545
# lambda: 0.103991597299
# Iteracion: 268
# Documento: 5003
# Ro: 0.0151919446647
# expected_log_beta: -16.7711049701 0.346545762961
# lambda: 0.103930850107
# Iteracion: 269
# Documento: 6101
# Ro: 0.0151651477285
# expected_log_beta: -16.7786607537 0.341293254002
# lambda: 0.10387113321
# Iteracion: 270
# Documento: 3017
# Ro: 0.0151384652947
# expected_log_beta: -16.7809688647 0.34142892614
# lambda: 0.103812427254
# Iteracion: 271
# Documento: 14647
# Ro: 0.0151118965883
# expected_log_beta: -16.7868408479 0.34139326574
# lambda: 0.10375471331
# Iteracion: 272
# Documento: 7278
# Ro: 0.0150854408414
# expected_log_beta: -16.7945356417 0.328952498856
# lambda: 0.103697972818
# Iteracion: 273
# Documento: 13185
# Ro: 0.0150590972929
# expected_log_beta: -16.7963024513 0.321962903165
# lambda: 0.103642187616
# Iteracion: 274
# Documento: 14407
# Ro: 0.0150328651892
# expected_log_beta: -16.7983098061 0.321727969276
# lambda: 0.103587339899
# Iteracion: 275
# Documento: 1865
# Ro: 0.0150067437833
# expected_log_beta: -16.8065771085 0.320491606263
# lambda: 0.10353341224
# Iteracion: 276
# Documento: 3612
# Ro: 0.014980732335
# expected_log_beta: -16.8089186808 0.310901344202
# lambda: 0.103480387565
# Iteracion: 277
# Documento: 5809
# Ro: 0.0149548301111
# expected_log_beta: -16.8157439431 0.308674649534
# lambda: 0.103428249142
# Iteracion: 278
# Documento: 4053
# Ro: 0.0149290363848
# expected_log_beta: -16.8177046498 0.305576520404
# lambda: 0.103376980586
# Iteracion: 279
# Documento: 2901
# Ro: 0.0149033504363
# expected_log_beta: -16.8339057721 0.290964773169
# lambda: 0.103326565852
# Iteracion: 280
# Documento: 4188
# Ro: 0.014877771552
# expected_log_beta: -16.8283573776 0.300438224307
# lambda: 0.103276989197
# Iteracion: 281
# Documento: 11750
# Ro: 0.0148522990248
# expected_log_beta: -16.8314507153 0.293964903323
# lambda: 0.103228235222
# Iteracion: 282
# Documento: 12298
# Ro: 0.0148269321541
# expected_log_beta: -16.8333982698 0.289659182269
# lambda: 0.103180288824
# Iteracion: 283
# Documento: 10306
# Ro: 0.0148016702456
# expected_log_beta: -16.8373661274 0.282088541844
# lambda: 0.103133135217
# Iteracion: 284
# Documento: 12417
# Ro: 0.0147765126111
# expected_log_beta: -16.8413495627 0.275321502684
# lambda: 0.103086759899
# Iteracion: 285
# Documento: 11779
# Ro: 0.0147514585687
# expected_log_beta: -16.8436277993 0.27686666027
# lambda: 0.103041148661
# Iteracion: 286
# Documento: 5549
# Ro: 0.0147265074425
# expected_log_beta: -16.842871439 0.277129025643
# lambda: 0.102996287596
# Iteracion: 287
# Documento: 9708
# Ro: 0.0147016585628
# expected_log_beta: -16.8546300823 0.270010756078
# lambda: 0.102952163058
# Iteracion: 288
# Documento: 6730
# Ro: 0.0146769112656
# expected_log_beta: -16.8592614117 0.266373714905
# lambda: 0.102908761672
# Iteracion: 289
# Documento: 3495
# Ro: 0.0146522648931
# expected_log_beta: -16.8572950803 0.264833871744
# lambda: 0.102866070343
# Iteracion: 290
# Documento: 10033
# Ro: 0.014627718793
# expected_log_beta: -16.8650296084 0.26542561391
# lambda: 0.102824076226
# Iteracion: 291
# Documento: 4980
# Ro: 0.014603272319
# expected_log_beta: -16.8665987564 0.253745435339
# lambda: 0.102782766736
# Iteracion: 292
# Documento: 8179
# Ro: 0.0145789248304
# expected_log_beta: -16.8632367492 0.255571397093
# lambda: 0.102742129536
# Iteracion: 293
# Documento: 9918
# Ro: 0.0145546756921
# expected_log_beta: -16.879050101 0.244925635983
# lambda: 0.102702152533
# Iteracion: 294
# Documento: 9304
# Ro: 0.0145305242747
# expected_log_beta: -16.8783774565 0.243379586663
# lambda: 0.102662823874
# Iteracion: 295
# Documento: 9684
# Ro: 0.0145064699543
# expected_log_beta: -16.8770681566 0.243689539324
# lambda: 0.102624131941
# Iteracion: 296
# Documento: 12747
# Ro: 0.0144825121122
# expected_log_beta: -16.8827250983 0.237205947529
# lambda: 0.102586065343
# Iteracion: 297
# Documento: 1838
# Ro: 0.0144586501353
# expected_log_beta: -16.8883325248 0.237780384271
# lambda: 0.102548612914
# Iteracion: 298
# Documento: 5593
# Ro: 0.0144348834159
# expected_log_beta: -16.8882633664 0.236443835161
# lambda: 0.102511763698
# Iteracion: 299
# Documento: 2737
# Ro: 0.0144112113513
# expected_log_beta: -16.8915247413 0.233349753261
# lambda: 0.102475506972
# Iteracion: 300
# Documento: 14036
# Ro: 0.0143876333444
# expected_log_beta: -16.8950147012 0.225041030942
# lambda: 0.102439832207
# Iteracion: 301
# Documento: 4870
# Ro: 0.0143641488027
# expected_log_beta: -16.9021469826 0.222688221515
# lambda: 0.102404729081
# Iteracion: 302
# Documento: 4257
# Ro: 0.0143407571394
# expected_log_beta: -16.897876013 0.223335032878
# lambda: 0.102370187477
# Iteracion: 303
# Documento: 12077
# Ro: 0.0143174577724
# expected_log_beta: -16.9004950725 0.219866240355
# lambda: 0.102336197478
# Iteracion: 304
# Documento: 5911
# Ro: 0.0142942501245
# expected_log_beta: -16.9063350549 0.220799863399
# lambda: 0.102302749353
# Iteracion: 305
# Documento: 12889
# Ro: 0.0142711336237
# expected_log_beta: -16.9054918412 0.213162229206
# lambda: 0.102269833556
# Iteracion: 306
# Documento: 4684
# Ro: 0.0142481077028
# expected_log_beta: -16.9141971379 0.207979222481
# lambda: 0.102237440738
# Iteracion: 307
# Documento: 5030
# Ro: 0.0142251717993
# expected_log_beta: -16.9146609509 0.211776249334
# lambda: 0.102205561716
# Iteracion: 308
# Documento: 7330
# Ro: 0.0142023253556
# expected_log_beta: -16.9165042097 0.204555023497
# lambda: 0.102174187496
# Iteracion: 309
# Documento: 14652
# Ro: 0.0141795678188
# expected_log_beta: -16.9199428299 0.204669784243
# lambda: 0.102143309252
# Iteracion: 310
# Documento: 1487
# Ro: 0.0141568986406
# expected_log_beta: -16.9243716077 0.197840150883
# lambda: 0.102112918326
# Iteracion: 311
# Documento: 5343
# Ro: 0.0141343172774
# expected_log_beta: -16.9260877604 0.19603309038
# lambda: 0.102083006229
# Iteracion: 312
# Documento: 6812
# Ro: 0.0141118231902
# expected_log_beta: -16.9315623912 0.191846446391
# lambda: 0.102053564631
# Iteracion: 313
# Documento: 11347
# Ro: 0.0140894158444
# expected_log_beta: -16.9279117411 0.195313172838
# lambda: 0.102024585358
# Iteracion: 314
# Documento: 11128
# Ro: 0.0140670947099
# expected_log_beta: -16.9318702271 0.187903596384
# lambda: 0.101996060398
# Iteracion: 315
# Documento: 5622
# Ro: 0.0140448592613
# expected_log_beta: -16.9321091296 0.183359824945
# lambda: 0.101967981894
# Iteracion: 316
# Documento: 3374
# Ro: 0.0140227089772
# expected_log_beta: -16.9370285221 0.183415540751
# lambda: 0.101940342133
# Iteracion: 317
# Documento: 8246
# Ro: 0.0140006433407
# expected_log_beta: -16.9380104735 0.1798637525
# lambda: 0.101913133544
# Iteracion: 318
# Documento: 10070
# Ro: 0.0139786618392
# expected_log_beta: -16.9437397349 0.17915429112
# lambda: 0.101886348709
# Iteracion: 319
# Documento: 4587
# Ro: 0.0139567639644
# expected_log_beta: -16.9441705429 0.177407112171
# lambda: 0.10185998034
# Iteracion: 320
# Documento: 2298
# Ro: 0.013934949212
# expected_log_beta: -16.9464262812 0.172103265901
# lambda: 0.101834021293
# Iteracion: 321
# Documento: 14730
# Ro: 0.0139132170821
# expected_log_beta: -16.9489157727 0.174251584009
# lambda: 0.101808464559
# Iteracion: 322
# Documento: 12062
# Ro: 0.0138915670788
# expected_log_beta: -16.9529567235 0.169618561485
# lambda: 0.101783303258
# Iteracion: 323
# Documento: 10408
# Ro: 0.0138699987101
# expected_log_beta: -16.9535934929 0.167314405511
# lambda: 0.101758530639
# Iteracion: 324
# Documento: 12870
# Ro: 0.0138485114885
# expected_log_beta: -16.9561069646 0.168409765643
# lambda: 0.101734140079
# Iteracion: 325
# Documento: 1233
# Ro: 0.0138271049299
# expected_log_beta: -16.9621290227 0.155057980188
# lambda: 0.101710125074
# Iteracion: 326
# Documento: 2978
# Ro: 0.0138057785545
# expected_log_beta: -16.9585156358 0.159724416854
# lambda: 0.101686479247
# Iteracion: 327
# Documento: 10123
# Ro: 0.0137845318865
# expected_log_beta: -16.9576254291 0.162824737435
# lambda: 0.101663196343
# Iteracion: 328
# Documento: 7311
# Ro: 0.0137633644535
# expected_log_beta: -16.9623292588 0.154498241365
# lambda: 0.101640270216
# Iteracion: 329
# Documento: 1226
# Ro: 0.0137422757875
# expected_log_beta: -16.963009626 0.158455995026
# lambda: 0.101617694831
# Iteracion: 330
# Documento: 114
# Ro: 0.0137212654238
# expected_log_beta: -16.9668627181 0.152635836947
# lambda: 0.101595464274
# Iteracion: 331
# Documento: 7702
# Ro: 0.0137003329018
# expected_log_beta: -16.9677800082 0.151623839578
# lambda: 0.101573572735
# Iteracion: 332
# Documento: 2050
# Ro: 0.0136794777643
# expected_log_beta: -16.9718714191 0.146284400244
# lambda: 0.101552014516
# Iteracion: 333
# Documento: 2261
# Ro: 0.0136586995581
# expected_log_beta: -16.9722654363 0.150049124858
# lambda: 0.101530784012
# Iteracion: 334
# Documento: 1660
# Ro: 0.0136379978333
# expected_log_beta: -16.9756129126 0.143002847754
# lambda: 0.10150987574
# Iteracion: 335
# Documento: 5517
# Ro: 0.0136173721438
# expected_log_beta: -16.9748530307 0.14463479215
# lambda: 0.101489284306
# Iteracion: 336
# Documento: 13014
# Ro: 0.013596822047
# expected_log_beta: -16.9795457762 0.138225472896
# lambda: 0.10146900441
# Iteracion: 337
# Documento: 6544
# Ro: 0.0135763471039
# expected_log_beta: -16.9807709854 0.137036667962
# lambda: 0.101449030863
# Iteracion: 338
# Documento: 12462
# Ro: 0.0135559468789
# expected_log_beta: -16.9822609917 0.134956106725
# lambda: 0.101429358563
# Iteracion: 339
# Documento: 6419
# Ro: 0.0135356209398
# expected_log_beta: -16.9835473277 0.135115365805
# lambda: 0.101409982495
# Iteracion: 340
# Documento: 11501
# Ro: 0.0135153688579
# expected_log_beta: -16.9832442122 0.133449587483
# lambda: 0.101390897747
# Iteracion: 341
# Documento: 114
# Ro: 0.013495190208
# expected_log_beta: -16.9860303983 0.132330477775
# lambda: 0.101372099489
# Iteracion: 342
# Documento: 10248
# Ro: 0.0134750845679
# expected_log_beta: -16.9854054816 0.134806232673
# lambda: 0.101353582984
# Iteracion: 343
# Documento: 10941
# Ro: 0.0134550515192
# expected_log_beta: -16.9874676486 0.131506243404
# lambda: 0.101335343578
# Iteracion: 344
# Documento: 9854
# Ro: 0.0134350906463
# expected_log_beta: -16.9916948028 0.127210816974
# lambda: 0.101317376699
# Iteracion: 345
# Documento: 7663
# Ro: 0.0134152015372
# expected_log_beta: -16.9930277758 0.121319297542
# lambda: 0.101299677859
# Iteracion: 346
# Documento: 1754
# Ro: 0.013395383783
# expected_log_beta: -16.9935106408 0.122201330981
# lambda: 0.101282242656
# Iteracion: 347
# Documento: 12303
# Ro: 0.0133756369778
# expected_log_beta: -16.9928734732 0.123470080462
# lambda: 0.10126506676
# Iteracion: 348
# Documento: 11198
# Ro: 0.0133559607192
# expected_log_beta: -16.9974679422 0.119730542791
# lambda: 0.101248145922
# Iteracion: 349
# Documento: 11976
# Ro: 0.0133363546078
# expected_log_beta: -16.9975622617 0.123287645232
# lambda: 0.101231475969
# Iteracion: 350
# Documento: 5306
# Ro: 0.0133168182471
# expected_log_beta: -16.9980328789 0.117729808044
# lambda: 0.101215052805
# Iteracion: 351
# Documento: 268
# Ro: 0.0132973512438
# expected_log_beta: -16.9990774791 0.118241623398
# lambda: 0.1011988724
# Iteracion: 352
# Documento: 8236
# Ro: 0.0132779532078
# expected_log_beta: -17.0034890443 0.112976399643
# lambda: 0.101182930805
# Iteracion: 353
# Documento: 3649
# Ro: 0.0132586237517
# expected_log_beta: -17.0025310367 0.115900601634
# lambda: 0.101167224137
# Iteracion: 354
# Documento: 5978
# Ro: 0.0132393624913
# expected_log_beta: -17.0062258504 0.110405149687
# lambda: 0.101151748583
# Iteracion: 355
# Documento: 14201
# Ro: 0.0132201690452
# expected_log_beta: -17.0056682187 0.114558502032
# lambda: 0.101136500399
# Iteracion: 356
# Documento: 4596
# Ro: 0.0132010430351
# expected_log_beta: -17.0073060329 0.10991521079
# lambda: 0.1011214759
# Iteracion: 357
# Documento: 13986
# Ro: 0.0131819840853
# expected_log_beta: -17.0109144926 0.105474793529
# lambda: 0.101106671475
# Iteracion: 358
# Documento: 14506
# Ro: 0.0131629918233
# expected_log_beta: -17.0086226722 0.1092791111
# lambda: 0.101092083577
# Iteracion: 359
# Documento: 8819
# Ro: 0.0131440658791
# expected_log_beta: -17.0101123801 0.108704508751
# lambda: 0.101077708717
# Iteracion: 360
# Documento: 2197
# Ro: 0.0131252058857
# expected_log_beta: -17.0128692369 0.104125009895
# lambda: 0.101063543468
# Iteracion: 361
# Documento: 3462
# Ro: 0.0131064114789
# expected_log_beta: -17.015945796 0.100923578844
# lambda: 0.101049584468
# Iteracion: 362
# Documento: 12483
# Ro: 0.0130876822972
# expected_log_beta: -17.0170680019 0.0989746241074
# lambda: 0.101035828408
# Iteracion: 363
# Documento: 9889
# Ro: 0.0130690179818
# expected_log_beta: -17.0164423376 0.101023666178
# lambda: 0.10102227204
# Iteracion: 364
# Documento: 3794
# Ro: 0.0130504181766
# expected_log_beta: -17.0163438076 0.100477295462
# lambda: 0.101008912172
# Iteracion: 365
# Documento: 9292
# Ro: 0.0130318825282
# expected_log_beta: -17.0167882767 0.0988595811824
# lambda: 0.100995745672
# Iteracion: 366
# Documento: 2155
# Ro: 0.0130134106858
# expected_log_beta: -17.0183200599 0.0973879679339
# lambda: 0.100982769457
# Iteracion: 367
# Documento: 11907
# Ro: 0.0129950023013
# expected_log_beta: -17.0193038844 0.0948395038539
# lambda: 0.1009699805
# Iteracion: 368
# Documento: 6734
# Ro: 0.0129766570292
# expected_log_beta: -17.0195568842 0.0974505552896
# lambda: 0.10095737582
# Iteracion: 369
# Documento: 1307
# Ro: 0.0129583745264
# expected_log_beta: -17.0222530172 0.0922898397451
# lambda: 0.100944952505
# Iteracion: 370
# Documento: 2496
# Ro: 0.0129401544527
# expected_log_beta: -17.0253317331 0.0895839085201
# lambda: 0.100932707678
# Iteracion: 371
# Documento: 3119
# Ro: 0.01292199647
# expected_log_beta: -17.0240613063 0.090107231801
# lambda: 0.100920638518
# Iteracion: 372
# Documento: 4877
# Ro: 0.012903900243
# expected_log_beta: -17.0253897729 0.0900246311381
# lambda: 0.100908742248
# Iteracion: 373
# Documento: 11670
# Ro: 0.0128858654387
# expected_log_beta: -17.0280472736 0.0868381281592
# lambda: 0.100897016147
# Iteracion: 374
# Documento: 3115
# Ro: 0.0128678917268
# expected_log_beta: -17.0295855077 0.0876499376441
# lambda: 0.100885457537
# Iteracion: 375
# Documento: 3594
# Ro: 0.0128499787792
# expected_log_beta: -17.0302711382 0.0853189049458
# lambda: 0.100874063782
# Iteracion: 376
# Documento: 794
# Ro: 0.0128321262702
# expected_log_beta: -17.0304325219 0.0874101149541
# lambda: 0.1008628323
# Iteracion: 377
# Documento: 2619
# Ro: 0.0128143338766
# expected_log_beta: -17.0322105464 0.0844106906993
# lambda: 0.100851760544
# Iteracion: 378
# Documento: 11109
# Ro: 0.0127966012776
# expected_log_beta: -17.030940268 0.083318631705
# lambda: 0.100840846014
# Iteracion: 379
# Documento: 9191
# Ro: 0.0127789281546
# expected_log_beta: -17.0342911513 0.0807778194067
# lambda: 0.100830086257
# Iteracion: 380
# Documento: 7977
# Ro: 0.0127613141915
# expected_log_beta: -17.0366737818 0.0791975234689
# lambda: 0.100819478858
# Iteracion: 381
# Documento: 4382
# Ro: 0.0127437590743
# expected_log_beta: -17.0345157428 0.0801852542223
# lambda: 0.100809021446
# Iteracion: 382
# Documento: 6794
# Ro: 0.0127262624913
# expected_log_beta: -17.0351943871 0.0771080319197
# lambda: 0.100798711685
# Iteracion: 383
# Documento: 13701
# Ro: 0.0127088241333
# expected_log_beta: -17.0369059537 0.0787302070568
# lambda: 0.100788547286
# Iteracion: 384
# Documento: 6312
# Ro: 0.0126914436931
# expected_log_beta: -17.0367087585 0.0799674313464
# lambda: 0.100778525989
# Iteracion: 385
# Documento: 14528
# Ro: 0.0126741208657
# expected_log_beta: -17.0396099997 0.0740565973747
# lambda: 0.100768645583
# Iteracion: 386
# Documento: 6799
# Ro: 0.0126568553484
# expected_log_beta: -17.0399757116 0.0760607875111
# lambda: 0.100758903887
# Iteracion: 387
# Documento: 2436
# Ro: 0.0126396468408
# expected_log_beta: -17.0402738797 0.0732227341001
# lambda: 0.100749298764
# Iteracion: 388
# Documento: 5647
# Ro: 0.0126224950443
# expected_log_beta: -17.0402168076 0.0738528432827
# lambda: 0.100739828106
# Iteracion: 389
# Documento: 10376
# Ro: 0.0126053996628
# expected_log_beta: -17.0410266406 0.0715841629437
# lambda: 0.100730489842
# Iteracion: 390
# Documento: 3183
# Ro: 0.0125883604021
# expected_log_beta: -17.0433598082 0.0704005047867
# lambda: 0.100721281936
# Iteracion: 391
# Documento: 9500
# Ro: 0.0125713769701
# expected_log_beta: -17.0422227578 0.0720663148702
# lambda: 0.100712202387
# Iteracion: 392
# Documento: 13131
# Ro: 0.012554449077
# expected_log_beta: -17.0440015609 0.0697212585686
# lambda: 0.100703249236
# ...
# lambda: 0.100006096084
# Iteracion: 874
# Documento: 8193
# Ro: 0.007932180623
# expected_log_beta: -17.1071751133 0.000598702985196
# lambda: 0.100006047819
# Iteracion: 875
# Documento: 3973
# Ro: 0.00792664387606
# expected_log_beta: -17.1071820007 0.000628419000196
# lambda: 0.100005999971
# Iteracion: 876
# Documento: 127
# Ro: 0.00792111650549
# expected_log_beta: -17.1071841508 0.000613055458809
# lambda: 0.100005952535
# Iteracion: 877
# Documento: 10673
# Ro: 0.0079155984861
# expected_log_beta: -17.1071808468 0.000611574196349
# lambda: 0.100005905507
# Iteracion: 878
# Documento: 2705
# Ro: 0.00791008979278
# expected_log_beta: -17.1071908019 0.000595343819471
# lambda: 0.100005858885
# Iteracion: 879
# Documento: 6721
# Ro: 0.00790459040053
# expected_log_beta: -17.1072081705 0.000581557487006
# lambda: 0.100005812664
# Iteracion: 880
# Documento: 12355
# Ro: 0.00789910028443
# expected_log_beta: -17.107216214 0.000589713396983
# lambda: 0.100005766841
# Iteracion: 881
# Documento: 6636
# Ro: 0.00789361941965
# expected_log_beta: -17.1072215249 0.000567243812518
# lambda: 0.100005721411
# Iteracion: 882
# Documento: 11218
# Ro: 0.00788814778146
# expected_log_beta: -17.1072137493 0.000574710564967
# lambda: 0.100005676372
# Iteracion: 883
# Documento: 2270
# Ro: 0.00788268534522
# expected_log_beta: -17.1072197464 0.000566238572001
# lambda: 0.100005631719
# Iteracion: 884
# Documento: 3727
# Ro: 0.00787723208637
# expected_log_beta: -17.1072272993 0.000565764180014
# lambda: 0.100005587448
# Iteracion: 885
# Documento: 14499
# Ro: 0.00787178798044
# expected_log_beta: -17.1072080788 0.000568699401993
# lambda: 0.100005543557
# Iteracion: 886
# Documento: 122
# Ro: 0.00786635300306
# expected_log_beta: -17.107229131 0.00056156924563
# lambda: 0.100005500043
# Iteracion: 887
# Documento: 6694
# Ro: 0.00786092712995
# expected_log_beta: -17.1072398694 0.000553542804208
# lambda: 0.1000054569
# Iteracion: 888
# Documento: 8741
# Ro: 0.0078555103369
# expected_log_beta: -17.107237589 0.000572533393338
# lambda: 0.100005414126
# Iteracion: 889
# Documento: 5564
# Ro: 0.00785010259981
# expected_log_beta: -17.1072334245 0.000554792365873
# lambda: 0.100005371718
# Iteracion: 890
# Documento: 7135
# Ro: 0.00784470389465
# expected_log_beta: -17.107242455 0.000547422019666
# lambda: 0.100005329672
# Iteracion: 891
# Documento: 9019
# Ro: 0.00783931419749
# expected_log_beta: -17.107248508 0.000540159418703
# lambda: 0.100005287984
# Iteracion: 892
# Documento: 5325
# Ro: 0.00783393348448
# expected_log_beta: -17.107258892 0.000520778613881
# lambda: 0.100005246652
# Iteracion: 893
# Documento: 8137
# Ro: 0.00782856173186
# expected_log_beta: -17.1072530539 0.000538991737213
# lambda: 0.100005205673
# Iteracion: 894
# Documento: 12525
# Ro: 0.00782319891595
# expected_log_beta: -17.1072652998 0.000509137576465
# lambda: 0.100005165042
# Iteracion: 895
# Documento: 4161
# Ro: 0.00781784501317
# expected_log_beta: -17.1072497654 0.00053310359648
# lambda: 0.100005124756
# Iteracion: 896
# Documento: 5129
# Ro: 0.0078125
# expected_log_beta: -17.1072604096 0.000517355582056
# lambda: 0.100005084813
# Iteracion: 897
# Documento: 8999
# Ro: 0.00780716385303
# expected_log_beta: -17.1072720237 0.000519512315585
# lambda: 0.100005045209
# Iteracion: 898
# Documento: 1301
# Ro: 0.00780183654892
# expected_log_beta: -17.1072590957 0.000519172750596
# lambda: 0.100005005942
# Iteracion: 899
# Documento: 1117
# Ro: 0.00779651806443
# expected_log_beta: -17.1072680698 0.000520593824545
# lambda: 0.100004967007
# Iteracion: 900
# Documento: 13638
# Ro: 0.00779120837638
# expected_log_beta: -17.1072768193 0.000494687658771
# lambda: 0.100004928404
# Iteracion: 901
# Documento: 4523
# Ro: 0.00778590746168
# expected_log_beta: -17.1072790581 0.000506781671304
# lambda: 0.100004890128
# Iteracion: 902
# Documento: 5133
# Ro: 0.00778061529735
# expected_log_beta: -17.1072982122 0.000487079058985
# lambda: 0.100004852176
# Iteracion: 903
# Documento: 13521
# Ro: 0.00777533186045
# expected_log_beta: -17.1072984145 0.000463330999054
# lambda: 0.100004814545
# Iteracion: 904
# Documento: 783
# Ro: 0.00777005712815
# expected_log_beta: -17.1072930746 0.000488653629067
# lambda: 0.100004777231
# Iteracion: 905
# Documento: 5590
# Ro: 0.0077647910777
# expected_log_beta: -17.1072945107 0.000489088716466
# lambda: 0.100004740233
# Iteracion: 906
# Documento: 9576
# Ro: 0.00775953368643
# expected_log_beta: -17.1072902636 0.000481526525051
# lambda: 0.100004703547
# Iteracion: 907
# Documento: 616
# Ro: 0.00775428493173
# expected_log_beta: -17.1073098631 0.000461373738958
# lambda: 0.100004667171
# Iteracion: 908
# Documento: 14566
# Ro: 0.00774904479111
# expected_log_beta: -17.1073215341 0.000460934388473
# lambda: 0.100004631101
# Iteracion: 909
# Documento: 2435
# Ro: 0.00774381324212
# expected_log_beta: -17.1073174167 0.000460162899764
# lambda: 0.100004595335
# Iteracion: 910
# Documento: 11425
# Ro: 0.00773859026242
# expected_log_beta: -17.1073165339 0.000454917395332
# lambda: 0.100004559869
# Iteracion: 911
# Documento: 10151
# Ro: 0.00773337582973
# expected_log_beta: -17.1073203916 0.000452439276568
# lambda: 0.100004524704
# Iteracion: 912
# Documento: 7662
# Ro: 0.00772816992186
# expected_log_beta: -17.1073144549 0.000462758547242
# lambda: 0.100004489834
# Iteracion: 913
# Documento: 6024
# Ro: 0.00772297251671
# expected_log_beta: -17.1073323356 0.000456762182364
# lambda: 0.100004455256
# Iteracion: 914
# Documento: 14383
# Ro: 0.00771778359222
# expected_log_beta: -17.1073229853 0.000463000545111
# lambda: 0.10000442097
# Iteracion: 915
# Documento: 10947
# Ro: 0.00771260312646
# expected_log_beta: -17.1073287646 0.000437169822827
# lambda: 0.100004386971
# Iteracion: 916
# Documento: 1548
# Ro: 0.00770743109753
# expected_log_beta: -17.1073319865 0.000440593907491
# lambda: 0.100004353258
# Iteracion: 917
# Documento: 9485
# Ro: 0.00770226748363
# expected_log_beta: -17.1073490197 0.000433423039117
# lambda: 0.100004319827
# Iteracion: 918
# Documento: 4298
# Ro: 0.00769711226305
# expected_log_beta: -17.1073373977 0.000438549979672
# lambda: 0.100004286673
# Iteracion: 919
# Documento: 7614
# Ro: 0.00769196541412
# expected_log_beta: -17.1073401879 0.000439060219116
# lambda: 0.100004253798
# Iteracion: 920
# Documento: 2678
# Ro: 0.0076868269153
# expected_log_beta: -17.1073392764 0.000425139608468
# lambda: 0.100004221198
# Iteracion: 921
# Documento: 9664
# Ro: 0.00768169674506
# expected_log_beta: -17.1073388921 0.000438831514659
# lambda: 0.10000418887
# Iteracion: 922
# Documento: 126
# Ro: 0.00767657488201
# expected_log_beta: -17.1073431201 0.00042083296544
# lambda: 0.100004156813
# Iteracion: 923
# Documento: 528
# Ro: 0.00767146130478
# expected_log_beta: -17.1073523431 0.000425643655578
# lambda: 0.100004125023
# Iteracion: 924
# Documento: 5604
# Ro: 0.00766635599213
# expected_log_beta: -17.1073555115 0.000406758172325
# lambda: 0.100004093497
# Iteracion: 925
# Documento: 4306
# Ro: 0.00766125892284
# expected_log_beta: -17.107364585 0.00041097238684
# lambda: 0.100004062235
# Iteracion: 926
# Documento: 1438
# Ro: 0.0076561700758
# expected_log_beta: -17.1073723217 0.000406870495421
# lambda: 0.100004031233
# Iteracion: 927
# Documento: 13902
# Ro: 0.00765108942997
# expected_log_beta: -17.1073561328 0.000408820565273
# lambda: 0.100004000488
# Iteracion: 928
# Documento: 13579
# Ro: 0.00764601696436
# expected_log_beta: -17.107361896 0.000405393760931
# lambda: 0.100003969999
# Iteracion: 929
# Documento: 1753
# Ro: 0.0076409526581
# expected_log_beta: -17.1073704763 0.00039290379579
# lambda: 0.100003939763
# Iteracion: 930
# Documento: 5942
# Ro: 0.00763589649034
# expected_log_beta: -17.1073753125 0.000388175642482
# lambda: 0.100003909779
# Iteracion: 931
# Documento: 1049
# Ro: 0.00763084844033
# expected_log_beta: -17.1073719887 0.000399384119446
# lambda: 0.100003880044
# Iteracion: 932
# Documento: 669
# Ro: 0.00762580848741
# expected_log_beta: -17.107381719 0.000379039448942
# lambda: 0.100003850554
# Iteracion: 933
# Documento: 7341
# Ro: 0.00762077661095
# expected_log_beta: -17.1073691212 0.000390356375246
# lambda: 0.100003821309
# Iteracion: 934
# Documento: 4225
# Ro: 0.00761575279042
# expected_log_beta: -17.1073833391 0.000380599016386
# lambda: 0.100003792307
# Iteracion: 935
# Documento: 10845
# Ro: 0.00761073700535
# expected_log_beta: -17.1073845985 0.000387463937341
# lambda: 0.100003763544
# Iteracion: 936
# Documento: 10253
# Ro: 0.00760572923536
# expected_log_beta: -17.1073849886 0.000386710255731
# lambda: 0.100003735019
# Iteracion: 937
# Documento: 12035
# Ro: 0.00760072946012
# expected_log_beta: -17.1073980755 0.000367790310323
# lambda: 0.10000370673
# Iteracion: 938
# Documento: 6492
# Ro: 0.00759573765938
# expected_log_beta: -17.10741056 0.000352695197279
# lambda: 0.100003678675
# Iteracion: 939
# Documento: 6311
# Ro: 0.00759075381296
# expected_log_beta: -17.1073959014 0.000359086904238
# lambda: 0.100003650851
# Iteracion: 940
# Documento: 5214
# Ro: 0.00758577790073
# expected_log_beta: -17.1074039305 0.000362546236756
# lambda: 0.100003623256
# Iteracion: 941
# Documento: 335
# Ro: 0.00758080990267
# expected_log_beta: -17.1073929765 0.000371487435067
# lambda: 0.10000359589
# Iteracion: 942
# Documento: 1757
# Ro: 0.0075758497988
# expected_log_beta: -17.1074036276 0.000364646601414
# lambda: 0.100003568748
# Iteracion: 943
# Documento: 4791
# Ro: 0.00757089756921
# expected_log_beta: -17.107408635 0.000356778106106
# lambda: 0.10000354183
# Iteracion: 944
# Documento: 13869
# Ro: 0.00756595319407
# expected_log_beta: -17.1074056402 0.000364310778598
# lambda: 0.100003515133
# Iteracion: 945
# Documento: 13146
# Ro: 0.00756101665361
# expected_log_beta: -17.1074018558 0.000360610120193
# lambda: 0.100003488656
# Iteracion: 946
# Documento: 4381
# Ro: 0.00755608792813
# expected_log_beta: -17.1074125074 0.000343751872892
# lambda: 0.100003462396
# Iteracion: 947
# Documento: 14642
# Ro: 0.00755116699801
# expected_log_beta: -17.1074266571 0.000338129545184
# lambda: 0.100003436352
# Iteracion: 948
# Documento: 12351
# Ro: 0.00754625384367
# expected_log_beta: -17.1074041991 0.000345727379328
# lambda: 0.10000341052
# Iteracion: 949
# Documento: 4049
# Ro: 0.00754134844563
# expected_log_beta: -17.1074234528 0.000347024222318
# lambda: 0.100003384901
# Iteracion: 950
# Documento: 1367
# Ro: 0.00753645078444
# expected_log_beta: -17.1074179626 0.000336482295745
# lambda: 0.100003359492
# Iteracion: 951
# Documento: 12296
# Ro: 0.00753156084076
# expected_log_beta: -17.1074285307 0.000334902335019
# lambda: 0.10000333429
# Iteracion: 952
# Documento: 12736
# Ro: 0.00752667859528
# expected_log_beta: -17.1074146896 0.000344442610194
# lambda: 0.100003309295
# Iteracion: 953
# Documento: 13678
# Ro: 0.00752180402878
# expected_log_beta: -17.1074184512 0.000342873888774
# lambda: 0.100003284505
# Iteracion: 954
# Documento: 11564
# Ro: 0.00751693712208
# expected_log_beta: -17.1074295582 0.000329130731337
# lambda: 0.100003259917
# Iteracion: 955
# Documento: 13540
# Ro: 0.00751207785609
# expected_log_beta: -17.1074278758 0.000338726066887
# lambda: 0.100003235529
# Iteracion: 956
# Documento: 7736
# Ro: 0.00750722621178
# expected_log_beta: -17.1074258164 0.000322747256843
# lambda: 0.10000321134
# Iteracion: 957
# Documento: 6096
# Ro: 0.00750238217017
# expected_log_beta: -17.1074385449 0.000322070167385
# lambda: 0.100003187348
# Iteracion: 958
# Documento: 12113
# Ro: 0.00749754571236
# expected_log_beta: -17.107433311 0.000331712025554
# lambda: 0.100003163552
# Iteracion: 959
# Documento: 4660
# Ro: 0.00749271681952
# expected_log_beta: -17.1074451452 0.000320929188317
# lambda: 0.10000313995
# Iteracion: 960
# Documento: 2648
# Ro: 0.00748789547286
# expected_log_beta: -17.1074490539 0.000313054524836
# lambda: 0.100003116542
# Iteracion: 961
# Documento: 9027
# Ro: 0.00748308165368
# expected_log_beta: -17.1074505809 0.000308108632117
# lambda: 0.100003093324
# Iteracion: 962
# Documento: 7848
# Ro: 0.00747827534332
# expected_log_beta: -17.1074542082 0.000304633617862
# lambda: 0.100003070293
# Iteracion: 963
# Documento: 3066
# Ro: 0.0074734765232
# expected_log_beta: -17.107443245 0.000308434937531
# lambda: 0.100003047448
# Iteracion: 964
# Documento: 228
# Ro: 0.00746868517479
# expected_log_beta: -17.1074524971 0.000301219133736
# lambda: 0.100003024789
# Iteracion: 965
# Documento: 14322
# Ro: 0.00746390127965
# expected_log_beta: -17.1074548374 0.000300698129032
# lambda: 0.100003002314
# Iteracion: 966
# Documento: 10908
# Ro: 0.00745912481937
# expected_log_beta: -17.1074519697 0.000306787700011
# lambda: 0.100002980022
# Iteracion: 967
# Documento: 9280
# Ro: 0.00745435577561
# expected_log_beta: -17.1074602979 0.000288896622354
# lambda: 0.100002957909
# Iteracion: 968
# Documento: 3441
# Ro: 0.0074495941301
# expected_log_beta: -17.1074665898 0.000288357135761
# lambda: 0.100002935977
# Iteracion: 969
# Documento: 6223
# Ro: 0.00744483986464
# expected_log_beta: -17.1074745118 0.000286078435235
# lambda: 0.10000291422
# Iteracion: 970
# Documento: 7952
# Ro: 0.00744009296106
# expected_log_beta: -17.1074681667 0.000288080617842
# lambda: 0.100002892639
# Iteracion: 971
# Documento: 7050
# Ro: 0.00743535340129
# expected_log_beta: -17.1074700413 0.000284381964904
# lambda: 0.100002871235
# Iteracion: 972
# Documento: 12223
# Ro: 0.00743062116729
# expected_log_beta: -17.1074663996 0.000288576753435
# lambda: 0.100002850001
# Iteracion: 973
# Documento: 12463
# Ro: 0.0074258962411
# expected_log_beta: -17.1074716267 0.00028717782378
# lambda: 0.100002828941
# Iteracion: 974
# Documento: 12485
# Ro: 0.0074211786048
# expected_log_beta: -17.1074766195 0.000280157872784
# lambda: 0.100002808049
# Iteracion: 975
# Documento: 13844
# Ro: 0.00741646824056
# expected_log_beta: -17.1074622262 0.00028457859356
# lambda: 0.100002787325
# Iteracion: 976
# Documento: 12322
# Ro: 0.00741176513058
# expected_log_beta: -17.107483998 0.000271783165256
# lambda: 0.10000276677
# Iteracion: 977
# Documento: 6642
# Ro: 0.00740706925714
# expected_log_beta: -17.1074769428 0.000280292587048
# lambda: 0.10000274638
# Iteracion: 978
# Documento: 8768
# Ro: 0.00740238060257
# expected_log_beta: -17.1074836389 0.000267692704839
# lambda: 0.100002726153
# Iteracion: 979
# Documento: 1738
# Ro: 0.00739769914925
# expected_log_beta: -17.1074831566 0.00027324965344
# lambda: 0.100002706088
# Iteracion: 980
# Documento: 10681
# Ro: 0.00739302487965
# expected_log_beta: -17.1074829474 0.000274749208372
# lambda: 0.100002686184
# Iteracion: 981
# Documento: 7546
# Ro: 0.00738835777626
# expected_log_beta: -17.1074785784 0.000271955726481
# lambda: 0.10000266644
# Iteracion: 982
# Documento: 11335
# Ro: 0.00738369782165
# expected_log_beta: -17.1074749631 0.000277353220073
# lambda: 0.100002646855
# Iteracion: 983
# Documento: 625
# Ro: 0.00737904499845
# expected_log_beta: -17.1074851065 0.000265771047138
# lambda: 0.100002627425
# Iteracion: 984
# Documento: 13012
# Ro: 0.00737439928933
# expected_log_beta: -17.1074927549 0.00027245451531
# lambda: 0.100002608153
# Iteracion: 985
# Documento: 9612
# Ro: 0.00736976067705
# expected_log_beta: -17.10750072 0.000256228718738
# lambda: 0.100002589034
# Iteracion: 986
# Documento: 2584
# Ro: 0.00736512914439
# expected_log_beta: -17.1074887684 0.000268949228675
# lambda: 0.100002570069
# Iteracion: 987
# Documento: 7109
# Ro: 0.00736050467422
# expected_log_beta: -17.1074928558 0.000263417075346
# lambda: 0.100002551255
# Iteracion: 988
# Documento: 11835
# Ro: 0.00735588724943
# expected_log_beta: -17.107505428 0.000250173950996
# lambda: 0.100002532591
# Iteracion: 989
# Documento: 12291
# Ro: 0.007351276853
# expected_log_beta: -17.1074935488 0.0002574845874
# lambda: 0.100002514077
# Iteracion: 990
# Documento: 6364
# Ro: 0.00734667346796
# expected_log_beta: -17.1075024312 0.000252898563979
# lambda: 0.100002495708
# Iteracion: 991
# Documento: 12780
# Ro: 0.00734207707738
# expected_log_beta: -17.1075030316 0.000253760748871
# lambda: 0.100002477488
# Iteracion: 992
# Documento: 231
# Ro: 0.00733748766439
# expected_log_beta: -17.1074989751 0.000260836608743
# lambda: 0.100002459413
# Iteracion: 993
# Documento: 1489
# Ro: 0.0073329052122
# expected_log_beta: -17.107507494 0.000251315459005
# lambda: 0.100002441482
# Iteracion: 994
# Documento: 11588
# Ro: 0.00732832970405
# expected_log_beta: -17.1075141617 0.000239277555136
# lambda: 0.100002423693
# Iteracion: 995
# Documento: 10833
# Ro: 0.00732376112323
# expected_log_beta: -17.1075080375 0.00024436830856
# lambda: 0.100002406045
# Iteracion: 996
# Documento: 8000
# Ro: 0.00731919945312
# expected_log_beta: -17.1075145915 0.000248860696367
# lambda: 0.100002388538
# Iteracion: 997
# Documento: 4980
# Ro: 0.00731464467711
# expected_log_beta: -17.1075159928 0.000238003686141
# lambda: 0.100002371171
# Iteracion: 998
# Documento: 520
# Ro: 0.00731009677869
# expected_log_beta: -17.107515328 0.00023497731637
# lambda: 0.100002353941
# Iteracion: 999
# Documento: 14060
# Ro: 0.00730555574136
# expected_log_beta: -17.1075225925 0.000240011994022
# lambda: 0.100002336847

# %%
lda.gamma[444]
# Out:
# array([ 0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.5       ,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001,
#         0.50000001,  0.50000001,  0.50000001,  0.50000001,  0.50000001])

# %%
1*np.random.gamma(100., 1./100., (20, 5))
# Out:
# array([[ 1.0798604 ,  0.97373394,  0.88739621,  1.03440563,  0.98806988],
#        [ 1.13795157,  1.06429252,  0.80639188,  1.06942342,  0.91533107],
#        [ 0.91871202,  0.90605241,  1.14016092,  1.00765478,  0.87824069],
#        [ 1.10465927,  0.97034079,  0.93218111,  0.91484871,  0.94797843],
#        [ 0.95292439,  0.96887915,  0.93923932,  1.19762181,  0.96959022],
#        [ 1.18304523,  0.99720983,  1.14736179,  1.13641531,  0.83999419],
#        [ 1.00538492,  1.03706921,  1.02907629,  0.85584699,  1.00059327],
#        [ 0.97266799,  1.00689861,  0.87516129,  0.86166215,  0.99133922],
#        [ 0.98128828,  0.88970856,  0.96094688,  0.98216586,  1.10912599],
#        [ 1.11726342,  1.08499997,  0.99982186,  0.84480264,  0.87377502],
#        [ 1.05386468,  1.15673207,  0.8894465 ,  0.9651385 ,  0.8962132 ],
#        [ 0.81650642,  0.87782913,  1.10108531,  0.85179599,  1.00440288],
#        [ 1.01389473,  0.98372603,  0.8860026 ,  1.07659528,  0.92636043],
#        [ 0.97371583,  1.075801  ,  1.07033607,  0.96963928,  1.04445838],
#        [ 0.966309  ,  0.90213396,  1.10051354,  0.93654568,  0.89685641],
#        [ 1.06366688,  1.17263099,  1.03561655,  0.90628459,  0.81901362],
#        [ 1.03140936,  1.03489682,  0.99392747,  0.94456866,  1.08439357],
#        [ 0.83835405,  0.87924254,  1.02590266,  1.08075412,  0.94894065],
#        [ 1.00677973,  1.09707305,  0.98554107,  0.91223473,  1.12469431],
#        [ 0.98711405,  0.95345965,  1.25429093,  0.99491281,  0.94713507]])

# %%
l = np.array([[1,2,3], [4,5,6]])
np.sum(l, axis=0)
# Out:
# array([5, 7, 9])

# %%
rand_state = np.random.RandomState(888)
rand_state.randn(10)
# Out:
# array([-0.17620087,  0.18887636,  0.82674718, -0.03244731, -0.65249942,
#        -0.10533938,  0.21777612,  0.5872815 ,  0.10023789, -1.09994668])

# %%
rand_state.randn(10)
# Out:
# array([-0.25530539,  0.40530438,  0.16266395,  1.04163462,  0.22432418,
#         0.69930445, -0.86554351, -1.39346831, -0.23668791, -0.75704191])
